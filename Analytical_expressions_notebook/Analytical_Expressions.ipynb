# %%
import sys
sys.path.append("../General_activity_package/")
from Activity import Latex_expressions, Python_expressions

# %%
# An example of generating LaTeX based code
Latex_expressions(2)
# Out:
# Computing Determinant and Adjugate...
# \begin{align*}
# \mu_{22} &= \frac{1}{D_{2}}\left(1\right) \\
# D_{2} &= N^{+}_{22} + 1 \\
# \end{align*}

# %%
# Printing formulas in Python
Python_expressions(2)
# Out:
# Computing Determinant and Adjugate...
# $\displaystyle \begin{align*}
# \mu_{22} &= \frac{1}{D_{2}}\left(1\right) \\
# D_{2} &= N^{+}_{22} + 1 \\
#  \end{align*}$

# %%
Python_expressions(3)
# Out:
# Computing Determinant and Adjugate...
# $\displaystyle \begin{align*}
# \mu_{22} &= \frac{1}{D_{3}}\left(N^{+}_{33} + 1\right) \\
# \mu_{32} &= \frac{1}{D_{3}}\left(- N^{+}_{32}\right) \\
# \mu_{23} &= \frac{1}{D_{3}}\left(- N^{+}_{23}\right) \\
# \mu_{33} &= \frac{1}{D_{3}}\left(N^{+}_{22} + 1\right) \\
# D_{3} &= N^{+}_{22} N^{+}_{33} + N^{+}_{22} - N^{+}_{23} N^{+}_{32} + N^{+}_{33} + 1 \\
#  \end{align*}$

# %%
Python_expressions(4)
# Out:
# Computing Determinant and Adjugate...
# $\displaystyle \begin{align*}
# \mu_{22} &= \frac{1}{D_{4}}\left(N^{+}_{33} N^{+}_{44} + N^{+}_{33} - N^{+}_{34} N^{+}_{43} + N^{+}_{44} + 1\right) \\
# \mu_{32} &= \frac{1}{D_{4}}\left(- N^{+}_{32} N^{+}_{44} - N^{+}_{32} + N^{+}_{34} N^{+}_{42}\right) \\
# \mu_{42} &= \frac{1}{D_{4}}\left(N^{+}_{32} N^{+}_{43} - N^{+}_{33} N^{+}_{42} - N^{+}_{42}\right) \\
# \mu_{23} &= \frac{1}{D_{4}}\left(- N^{+}_{23} N^{+}_{44} - N^{+}_{23} + N^{+}_{24} N^{+}_{43}\right) \\
# \mu_{33} &= \frac{1}{D_{4}}\left(N^{+}_{22} N^{+}_{44} + N^{+}_{22} - N^{+}_{24} N^{+}_{42} + N^{+}_{44} + 1\right) \\
# \mu_{43} &= \frac{1}{D_{4}}\left(- N^{+}_{22} N^{+}_{43} + N^{+}_{23} N^{+}_{42} - N^{+}_{43}\right) \\
# \mu_{24} &= \frac{1}{D_{4}}\left(N^{+}_{23} N^{+}_{34} - N^{+}_{24} N^{+}_{33} - N^{+}_{24}\right) \\
# \mu_{34} &= \frac{1}{D_{4}}\left(- N^{+}_{22} N^{+}_{34} + N^{+}_{24} N^{+}_{32} - N^{+}_{34}\right) \\
# ...

# %%
Python_expressions(5)
# Out:
# Computing Determinant and Adjugate...
# $\displaystyle \begin{align*}
# \mu_{22} &= \frac{1}{D_{5}}\left(N^{+}_{33} N^{+}_{44} N^{+}_{55} + N^{+}_{33} N^{+}_{44} - N^{+}_{33} N^{+}_{45} N^{+}_{54} + N^{+}_{33} N^{+}_{55} + N^{+}_{33} - N^{+}_{34} N^{+}_{43} N^{+}_{55} - N^{+}_{34} N^{+}_{43} + N^{+}_{34} N^{+}_{45} N^{+}_{53} + N^{+}_{35} N^{+}_{43} N^{+}_{54} - N^{+}_{35} N^{+}_{44} N^{+}_{53} - N^{+}_{35} N^{+}_{53} + N^{+}_{44} N^{+}_{55} + N^{+}_{44} - N^{+}_{45} N^{+}_{54} + N^{+}_{55} + 1\right) \\
# \mu_{32} &= \frac{1}{D_{5}}\left(- N^{+}_{32} N^{+}_{44} N^{+}_{55} - N^{+}_{32} N^{+}_{44} + N^{+}_{32} N^{+}_{45} N^{+}_{54} - N^{+}_{32} N^{+}_{55} - N^{+}_{32} + N^{+}_{34} N^{+}_{42} N^{+}_{55} + N^{+}_{34} N^{+}_{42} - N^{+}_{34} N^{+}_{45} N^{+}_{52} - N^{+}_{35} N^{+}_{42} N^{+}_{54} + N^{+}_{35} N^{+}_{44} N^{+}_{52} + N^{+}_{35} N^{+}_{52}\right) \\
# ...
